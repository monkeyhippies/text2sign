# %%
# !pip install moviepy
# Out:
# ...
#   Created wheel for mogrify: filename=mogrify-0.1-cp36-none-any.whl size=4431 sha256=e6dee432c816bc725a3c1b1a2493c8b054b81a5e5fd60e09cbf1223512c75804
#   Stored in directory: /tmp/.cache/pip/wheels/01/75/3e/c8d008428b66e65f937b5a9bd407041a6d786d782d5a56bdc4
# Successfully built mogrify
# ...

# %%
from moviepy.editor import *

# %%
# !apt install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   i965-va-driver libaacs0 libass5 libavc1394-0 libavcodec57 libavdevice57
#   libavfilter6 libavformat57 libavresample3 libavutil55 libbdplus0 libbluray1
#   libbs2b0 libcaca0 libcdio-cdda1 libcdio-paranoia1 libcdio13 libchromaprint1
#   libcrystalhd3 libdc1394-22 libebur128-1 libflite1 libfribidi0 libgme0
#   libiec61883-0 libjack-jackd2-0 libmpg123-0 libnuma1 libopenal-data
#   libopenal1 libopencv-core2.4v5 libopencv-imgproc2.4v5 libopenmpt0 libopus0
#   libpgm-5.2-0 libpostproc54 libraw1394-11 librubberband2 libsamplerate0
#   libsdl2-2.0-0 libshine3 libslang2 libsnappy1v5 libsndio6.1 libsodium18
#   libsoxr0 libspeex1 libssh-gcrypt-4 libswresample2 libswscale4 libtbb2
#   libtheora0 libusb-1.0-0 libva-drm1 libva-x11-1 libva1 libvdpau-va-gl1
#   libvdpau1 libvpx4 libx264-148 libx265-95 libxss1 libxvidcore4 libzmq5
# ...

# %%
# !rm train-video.mp4
# !ffmpeg -i ../input/y2mate.com\ -\ tutting_to_music_tutorial_1_thefatrat_unity_how_to_finger_tut_WTS1f1zcf2A_360p.mp4 -ss 00:04:30 -t 00:05:00 -async 1 train-video.mp4
# Out:
# rm: cannot remove 'train-video.mp4': No such file or directory
# ffmpeg: /opt/conda/lib/./libuuid.so.1: no version information available (required by /usr/lib/x86_64-linux-gnu/libSM.so.6)
# ffmpeg version 3.2.14-1~deb9u1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 6.3.0 (Debian 6.3.0-18+deb9u1) 20170516
# ...

# %%
# !rm -rf frame_images/
# !mkdir frame_images/

# %%
# !ffmpeg -i train-video.mp4 frame_images/train-video-%05d.jpg -hide_banner
# Out:
# ffmpeg: /opt/conda/lib/./libuuid.so.1: no version information available (required by /usr/lib/x86_64-linux-gnu/libSM.so.6)
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'train-video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.56.101
#   Duration: 00:05:00.02, start: 0.000000, bitrate: 438 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x360 [SAR 1:1 DAR 16:9], 304 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# [swscaler @ 0x55ae7f390c40] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'frame_images/train-video-%05d.jpg':
#   Metadata:
#     major_brand     : isom
# ...

# %%
# !du -hs frame_images/
# Out:
# 85M	frame_images/

# %%
# !tar -czvf train-images.tar.gz frame_images
# Out:
# frame_images/
# frame_images/train-video-04562.jpg
# frame_images/train-video-02879.jpg
# frame_images/train-video-04944.jpg
# frame_images/train-video-06317.jpg
# frame_images/train-video-01486.jpg
# frame_images/train-video-05740.jpg
# frame_images/train-video-03257.jpg
# frame_images/train-video-06422.jpg
# frame_images/train-video-00851.jpg
# frame_images/train-video-05593.jpg
# frame_images/train-video-01854.jpg
# frame_images/train-video-03791.jpg
# frame_images/train-video-03250.jpg
# frame_images/train-video-04304.jpg
# frame_images/train-video-03589.jpg
# frame_images/train-video-05935.jpg
# frame_images/train-video-00877.jpg
# frame_images/train-video-02149.jpg
# frame_images/train-video-06102.jpg
# frame_images/train-video-00591.jpg
# frame_images/train-video-00027.jpg
# frame_images/train-video-00858.jpg
# frame_images/train-video-01591.jpg
# frame_images/train-video-01259.jpg
# frame_images/train-video-00840.jpg
# frame_images/train-video-02066.jpg
# ...

# %%
from IPython.display import FileLinks
FileLinks('.') # input argument is specified folder
# Out:
# ./
#   train-video.mp4
#   __notebook_source__.ipynb
#   train-images.tar.gz
# ./frame_images/
#   train-video-04562.jpg
#   train-video-02879.jpg
#   train-video-04944.jpg
#   train-video-06317.jpg
#   train-video-01486.jpg
#   train-video-05740.jpg
#   train-video-03257.jpg
#   train-video-06422.jpg
#   train-video-00851.jpg
#   train-video-05593.jpg
#   train-video-01854.jpg
#   train-video-03791.jpg
#   train-video-03250.jpg
#   train-video-04304.jpg
#   train-video-03589.jpg
#   train-video-05935.jpg
#   train-video-00877.jpg
#   train-video-02149.jpg
#   train-video-06102.jpg
#   train-video-00591.jpg
#   train-video-00027.jpg
#   train-video-00858.jpg
#   train-video-01591.jpg
#   train-video-01259.jpg
#   train-video-00840.jpg
#   train-video-02066.jpg
#   train-video-05508.jpg
#   train-video-01183.jpg
#   train-video-04708.jpg
#   train-video-06740.jpg
#   train-video-01872.jpg
#   train-video-05088.jpg
#   train-video-06726.jpg
#   train-video-06807.jpg
# ...

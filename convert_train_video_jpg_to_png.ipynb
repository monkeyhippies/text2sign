# %%
# !git clone https://github.com/monkeyhippies/text2sign.git
# Out:
# Cloning into 'text2sign'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 23 (delta 7), reused 19 (delta 3), pack-reused 0
# Unpacking objects: 100% (23/23), done.

# %%
# !mv text2sign/train-images.tar.gz .

# %%
# !tar -zxvf train-images.tar.gz

# %%
# !apt-get update && apt-get install -y imagemagick

# %%
# !mogrify -format png frame_images/*.jpg

# %%
# !rm -rf frame_images/*.jpg

# %%
# !tar -czvf train-video-png.tar.gz frame_images/
# Out:
# frame_images/
# frame_images/train-video-04753.png
# frame_images/train-video-00258.png
# frame_images/train-video-03699.png
# frame_images/train-video-07173.png
# frame_images/train-video-03245.png
# frame_images/train-video-01930.png
# frame_images/train-video-01376.png
# frame_images/train-video-06147.png
# frame_images/train-video-03938.png
# frame_images/train-video-00862.png
# frame_images/train-video-04641.png
# frame_images/train-video-06598.png
# frame_images/train-video-04107.png
# frame_images/train-video-01797.png
# frame_images/train-video-02397.png
# frame_images/train-video-05532.png
# frame_images/train-video-03759.png
# frame_images/train-video-06667.png
# frame_images/train-video-00981.png
# frame_images/train-video-06106.png
# frame_images/train-video-06911.png
# frame_images/train-video-03951.png
# frame_images/train-video-05490.png
# frame_images/train-video-06331.png
# frame_images/train-video-02186.png
# frame_images/train-video-06797.png
# ...

# %%
# !mkdir subset_frame_images/
# !cp frame_images/train-video-00*.png subset_frame_images/

# %%
# !ls subset_frame_images/ | wc -l
# Out:
# 999

# %%
# !tar -czvf train-video-png-subset.tar.gz subset_frame_images/
# Out:
# subset_frame_images/
# subset_frame_images/train-video-00258.png
# subset_frame_images/train-video-00862.png
# subset_frame_images/train-video-00981.png
# subset_frame_images/train-video-00615.png
# subset_frame_images/train-video-00751.png
# subset_frame_images/train-video-00100.png
# subset_frame_images/train-video-00392.png
# subset_frame_images/train-video-00832.png
# subset_frame_images/train-video-00466.png
# subset_frame_images/train-video-00690.png
# subset_frame_images/train-video-00508.png
# subset_frame_images/train-video-00372.png
# subset_frame_images/train-video-00384.png
# subset_frame_images/train-video-00934.png
# subset_frame_images/train-video-00028.png
# subset_frame_images/train-video-00057.png
# subset_frame_images/train-video-00706.png
# subset_frame_images/train-video-00473.png
# subset_frame_images/train-video-00884.png
# subset_frame_images/train-video-00347.png
# subset_frame_images/train-video-00358.png
# subset_frame_images/train-video-00834.png
# ...
